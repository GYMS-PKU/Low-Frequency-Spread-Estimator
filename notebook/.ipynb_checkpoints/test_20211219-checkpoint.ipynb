# %% [markdown]
# ## 初步认识股票日内平均价差（2021.12.19）

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import importlib
import sys
sys.path.append('C:/Users/Administrator/Desktop/Repositories/Low-Frequency-Spread-Estimator')


from dataloader.dataloader import DataLoader

# %%
importlib.reload(dataloader.dataloader)
from dataloader.dataloader import DataLoader

# %%
DL = DataLoader()
data = DL.load()

# %% [markdown]
# #### 任意绘制一个股票的平均日内价差2019年走势

# %%
plt.figure(figsize=(12,4), dpi=150)
plt.subplot(1,2,1)
plt.plot(data.spread[:,1])
plt.title(data.order_code_dic[1])
plt.subplot(1,2,2)
plt.plot(data.spread[:,10])
plt.title(data.order_code_dic[10])
plt.show()

# %% [markdown]
# ### 简易测试几个随意构造的价差估计器的截面平均corr

# %%
signal = data.data_dic['high'] / data.data_dic['low']
corr = []
for i in range(len(data.spread)):
    se = ~np.isnan(signal[i])
    corr.append(np.corrcoef(np.log(data.spread[i][se]), signal[i][se])[0, 1])
corr = np.array(corr)
np.mean(corr)
# Out:
# 0.17727252146101607

# %%
np.sum(corr>0)
# Out:
# 241

# %%
from time import time
t = time()
for j in range(100):
    corr = []
    for i in range(len(data.spread)):
        se = ~np.isnan(signal[i])
        corr.append(np.corrcoef(np.log(data.spread[i][se]), signal[i][se])[0, 1])
time() - t
# Out:
# 1.9390432834625244

# %%
t = time()
for j in range(100):
    corr = np.zeros(len(data.spread))
    for i in range(len(data.spread)):
        se = ~np.isnan(signal[i])
        corr[i] = (np.mean(np.log(data.spread[i][se])*signal[i][se])-np.mean(np.log(data.spread[i][se]))*
                    np.mean(np.log(signal[i][se])))
time() - t
# Out:
# 1.440427541732788

# %%
data.start_date
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_4268/4016956597.py in <module>
# ----> 1 data.start_date
#
# AttributeError: 'Data' object has no attribute 'start_date'
