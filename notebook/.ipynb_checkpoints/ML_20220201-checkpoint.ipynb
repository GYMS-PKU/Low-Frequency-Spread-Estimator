# %% [markdown]
# ## 使用ML方法组合估计器

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import importlib
import sys
sys.path.append('C:/Users/Administrator/Desktop/Repositories/Low-Frequency-Spread-Estimator')
sys.path.append('C:/Users/Handsome Bad Guy/Desktop/Repositories/Low-Frequency-Spread-Estimator')

from SpreadEstimator.SpreadEstimator import SpreadEstimator
from mytools.AutoTester import AutoTester

from time import time

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
import torch.optim as optim

from sklearn.linear_model import LinearRegression

# %%
se = SpreadEstimator()
univ = ~np.isnan(se.data.data_dic['close'])  # 合法的univ

# %% [markdown]
# #### 构造因子矩阵

# %%
sig = {}

beta = 'prod{tsmean{powv{minus{logv{high},logv{low}},2},2},2}'
gamma = 'powv{minus{logv{tsmax{high,2}},logv{tsmin{low,2}}},2}'
alpha = 'div{prod{' + 'powv{' + beta + ',0.5},0.4142},0.1716}'
fml = 'minus{' + alpha + ',' + 'powv{' + 'div{' + gamma + ',0.1716},0.5}}'
fml = 'div{' + 'minus{expv{' + fml + '},1},' + 'add{expv{' + fml + '},1}}'
fml = 'condition{' + 'ge{' + fml +',0},' + fml + ',add{minus{close,close},0}}'
fml = 'tsmean{' + fml + ',20}'
stats, signal = se.test_factor(fml, corr_type='linear', method='cs', spread_type='relative_spread')
sig['HL'] = signal


a = 'tsdelta{logv{close},1}'
b = 'tsdelay{tsdelta{logv{close},1},1}'
fml = 'prod{' + a + ',' + b +'}'
fml = 'condition{' + 'ge{' + fml +',0},' + fml + ',add{minus{close,close},0}}'
fml = 'tsmean{' + fml + ',20}'
fml = 'powv{' + fml + ',0.5}'
stats, signal = se.test_factor(fml, corr_type='linear', method='cs', spread_type='spread')
sig['ROLL'] = signal

a = 'minus{logv{tsdelay{close,1}},div{add{logv{tsdelay{high,1}},logv{tsdelay{low,1}}},2}}'
b = 'minus{logv{tsdelay{close,1}},div{add{logv{high},logv{low}},2}}'
fml = 'prod{' + a + ',' + b +'}'
fml = 'condition{' + 'ge{' + fml +',0},' + fml + ',add{minus{close,close},0}}'
fml = 'tsmean{' + fml + ',20}'
fml = 'powv{' + fml + ',0.5}'
stats, signal = se.test_factor(fml, corr_type='linear', method='cs', spread_type='relative_spread')
sig['CHL'] = signal

signal = np.zeros((sig['HL'].shape[0], sig['HL'].shape[1], 3), dtype=np.float32)
signal[:, :, 0] = sig['CHL']
signal[:, :, 1] = sig['HL']
signal[:, :, 2] = sig['ROLL']
# Out:
# mean corr: -0.1554, positive_corr_ratio: 0.0000, corr_IR: -2.3100
# mean corr: 0.0994, positive_corr_ratio: 0.9279, corr_IR: 1.2409
# mean corr: -0.2317, positive_corr_ratio: 0.0000, corr_IR: -3.9265

# %%
def get_xy(x,y,univ):
    xx = []
    yy = []
    for i in range(len(x)):
        se = univ[i] & (~np.isnan(y[i]))
        for j in range(x.shape[2]):
            se = se & (~np.isnan(x[i,:,j]))
        if np.sum(se) == 0:
            continue
        xx.append(x[i, se, :])
        yy.append(y[i,se])
    return np.vstack(xx), np.hstack(yy)

# %%
rel_sp = se.data.spread_dic['relative_spread'].copy()
back = 20
for i in range(rel_sp.shape[0]):
    if i < back - 1:
        rel_sp[i] = np.nan
    else:
        rel_sp[i] = np.nanmean(se.data.spread_dic['relative_spread'][i-back+1:i+1],axis=0)
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_36184/453479782.py:7: RuntimeWarning: Mean of empty slice
#   rel_sp[i] = np.nanmean(se.data.spread_dic['relative_spread'][i-back+1:i+1],axis=0)

# %%
# signal[np.isnan(signal)] = 0.00
rel_sp = se.data.spread_dic['relative_spread'].copy()
x, y = get_xy(signal, rel_sp, univ)

# %% [markdown]
# #### 测试NN

# %%
sys.path.append('C:/Users/Administrator/Desktop/Daily-Frequency-Quant/QBG')
sys.path.append('C:/Users/HBG/Desktop/Repositories/Daily-Frequency-Quant/QBG')

from Model.MyDeepModel import *
from Model.Loss import *
from Model.tools.fitting_tools import *
from Model.tools.test_tools import *

# %%
device = 'cuda'
x = torch.Tensor(x).to(device)
y = torch.Tensor(y).to(device).unsqueeze(-1)

# %%
x.shape
# Out:
# torch.Size([448650, 3])

# %% [markdown]
# #### Linear

# %%
n = 1

model = nn.Linear(n, 1).to(device)
# model = GateNet(input_dim=2, output_dim=1, dropout=0.2, alpha=0.2).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=2e-2, weight_decay=0)
loss_func = MSELoss()

best_IC = 0

top =univ
t = time()
for i in range(10000):
    model.train()
    optimizer.zero_grad()
    loss = loss_func(model(x[:,:n]), y[:,:n])
    loss.backward()
    optimizer.step()
    
    if (i + 1) % 1000 == 0:
        model.eval()
        print('epoch {}'.format(i + 1))
        print('loss: {:.4f}, time used: {:.4f}s'.format(np.sqrt(float(loss))*1e4, time()-t))
        print('test loss: {:.4f}, time used: {:.4f}s'.format(np.sqrt(float(loss_func(model(x[:,:n]), y[:,:n])))*1e4, time()-t))
        corr = test(model, signal[:,:,:n], rel_sp, univ, 20, 240)
        print('vs IC: {:.4f}'.format(np.mean(corr)))
        print()
# Out:
# epoch 1000
# loss: 5.2630, time used: 0.7258s
# test loss: 5.2630, time used: 0.7258s
# vs IC: 0.1928
#
# epoch 2000
# loss: 5.2630, time used: 1.2858s
# test loss: 5.2630, time used: 1.2858s
# vs IC: 0.1928
#
# epoch 3000
# loss: 38.6343, time used: 1.8378s
# test loss: 28.6758, time used: 1.8378s
# vs IC: 0.1928
#
# epoch 4000
# loss: 5.2630, time used: 2.3848s
# test loss: 5.2630, time used: 2.3858s
# vs IC: 0.1928
#
# epoch 5000
# loss: 14.5634, time used: 2.9343s
# test loss: 19.3511, time used: 2.9343s
# vs IC: 0.1928
#
# epoch 6000
# loss: 5.2630, time used: 3.4881s
# test loss: 5.2630, time used: 3.4881s
# vs IC: 0.1928
#
# epoch 7000
# loss: 5.2630, time used: 4.0437s
# test loss: 5.2630, time used: 4.0447s
# vs IC: 0.1928
#
# epoch 8000
# loss: 5.2632, time used: 4.5932s
# test loss: 5.2640, time used: 4.5942s
# vs IC: 0.1928
#
# epoch 9000
# loss: 5.2630, time used: 5.1411s
# test loss: 5.2630, time used: 5.1411s
# vs IC: 0.1928
#
# epoch 10000
# ...

# %% [markdown]
# #### GateNet

# %%
class GateNet(nn.Module):
    def __init__(self, input_dim: int, output_dim: int, dropout: float = 0.7, alpha: float = 0.2):
        super(GateNet, self).__init__()
        self.input_dim = input_dim
        self.output_Dim = output_dim

        self.Dense1 = nn.Linear(input_dim, 16)
        self.Dense2 = nn.Linear(16, 8)
        self.Dense3 = nn.Linear(8, 8)
        self.Dense4 = nn.Linear(8, output_dim)

        self.gate0 = Gate(input_dim)
        self.gate1 = Gate(16)
        self.gate2 = Gate(8)
        self.gate3 = Gate(8)

        self.act = nn.LeakyReLU(alpha)

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = self.act(self.Dense1(self.gate0(self.dropout(x))))
        x = self.act(self.Dense2(self.gate1(self.dropout(x))))
        x = x + self.dropout(self.gate3(self.act(self.Dense3(self.gate2(self.dropout(x))))))
        x = self.Dense4(x)
        return x
    
    
class NN(nn.Module):
    def __init__(self, input_dim: int, output_dim: int, dropout: float = 0.7, alpha: float = 0.2):
        super(NN, self).__init__()
        self.input_dim = input_dim
        self.output_Dim = output_dim

        self.Dense1 = nn.Linear(input_dim, 4)
        self.Dense2 = nn.Linear(4, 4)
        self.Dense4 = nn.Linear(4, output_dim)
        self.act = nn.LeakyReLU(alpha)

    def forward(self, x):
        # return self.Dense1(x)
        x = self.act(self.Dense1(x))
        x = self.act(self.Dense2(x))
        return self.Dense4(x)

# %%
n = 3
model = NN(input_dim=n, output_dim=1, dropout=0.0, alpha=0.2).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=3e-2, weight_decay=0)
loss_func = MSELoss()

t = time()
for i in range(10000):
    model.train()
    optimizer.zero_grad()
    loss = loss_func(model(x[:,:n]), y[:,:n])
    loss.backward()
    optimizer.step()
    
    if (i + 1) % 1000 == 0:
        model.eval()
        print('epoch {}'.format(i + 1))
        print('loss: {:.4f}, time used: {:.4f}s'.format(np.sqrt(float(loss))*1e4, time()-t))
        print('test loss: {:.4f}, time used: {:.4f}s'.format(np.sqrt(float(loss_func(model(x[250000:,:n]), y[250000:,:n])))*1e4, time()-t))
        corr = test(model, signal[:,:,:n], se.data.spread_dic['relative_spread'], univ, 20, 240)
        print('vs IC: {:.4f}'.format(np.mean(corr)))
# Out:
# epoch 1000
# loss: 4.3727, time used: 24.8756s
# test loss: 4.2488, time used: 24.8766s
# vs IC: -0.1266
# epoch 2000
# loss: 4.2015, time used: 50.4022s
# test loss: 4.1013, time used: 50.4032s
# vs IC: -0.0912
# epoch 3000
# loss: 4.1808, time used: 76.0209s
# test loss: 4.0904, time used: 76.0219s
# vs IC: 0.1212
# epoch 4000
# loss: 4.1689, time used: 102.5365s
# test loss: 4.0861, time used: 102.5375s
# vs IC: 0.1534
# epoch 5000
# loss: 4.1614, time used: 128.0142s
# test loss: 4.0857, time used: 128.0152s
# vs IC: 0.1585
# epoch 6000
# loss: 4.1581, time used: 152.9519s
# test loss: 4.0870, time used: 152.9529s
# vs IC: 0.1592
# epoch 7000
# loss: 4.1682, time used: 177.8943s
# test loss: 4.0990, time used: 177.8953s
# vs IC: 0.1567
# epoch 8000
# loss: 4.1779, time used: 202.8259s
# test loss: 4.0953, time used: 202.8269s
# vs IC: 0.1506
# epoch 9000
# loss: 4.1877, time used: 227.7674s
# test loss: 4.1273, time used: 227.7684s
# vs IC: 0.1273
# epoch 10000
# ...

# %%
import jqdatasdk

jqdatasdk.auth('18316887409', '887409')
from jqdatasdk import *
# Out:
# 提示：当前环境 pandas 版本高于 0.25，get_price 与 get_fundamentals_continuously 接口 panel 参数将固定为 False
# 注意：0.25 以上版本 pandas 不支持 panel，如使用该数据结构和相关函数请注意修改
# auth success

# %%
get_price(['000001.XSHE','000002.XSHE'], start_date='2020-01-02',end_date='2020-01-02', fq=None)
# Out:
#         time         code   open  close   high    low       volume  \
# 0 2020-01-02  000001.XSHE  16.65  16.87  16.95  16.55  153023187.0
# 1 2020-01-02  000002.XSHE  32.80  32.56  33.60  32.51  101213040.0
#
#           money
# 0  2.571196e+09
# 1  3.342374e+09

# %%
import os
data_path = 'D:/Documents/学习资料/DailyData/data'
days = os.listdir(data_path)
names = ['open', 'low', 'high', 'close']
for day in days:
    df = pd.read_csv('{}/{}'.format(data_path, day))
    codes = df['Unnamed: 0'].values
    new_codes = []
    for i in range(len(codes)):
        code = codes[i]
        code = str(code)
        while len(code) < 6:
            code = '0' + code
        code = code + '.XSHE'
        new_codes.append(code)
    p = get_price(new_codes, start_date='2020-{}-{}'.format(day[:2], day[2:4]),
                  end_date='2020-{}-{}'.format(day[:2], day[2:4]), fq=None)
    break

# %%
p.sort_values('code', inplace=False)
p
# Out:
#            time         code   open  close   high    low      volume  \
# 0    2020-01-02  002233.XSHE  12.74  12.79  13.28  12.53  39594729.0
# 1    2020-01-02  002897.XSHE  27.05  27.69  27.85  26.83   6627312.0
# 2    2020-01-02  002906.XSHE  12.02  12.22  12.25  11.92   5040717.0
# 3    2020-01-02  002596.XSHE   6.58   6.63   6.73   6.53  36260890.0
# 4    2020-01-02  000988.XSHE  20.43  20.85  20.98  20.35  36037956.0
# ...         ...          ...    ...    ...    ...    ...         ...
# 2076 2020-01-02  000150.XSHE   4.83   4.86   4.86   4.80  13486606.0
# 2077 2020-01-02  300011.XSHE   5.95   6.04   6.04   5.93   6742696.0
# 2078 2020-01-02  000676.XSHE   9.18   9.67   9.83   9.07  56411557.0
# 2079 2020-01-02  000070.XSHE  11.02  11.15  11.26  10.98  23464004.0
# 2080 2020-01-02  002130.XSHE   4.96   4.98   5.00   4.93  18639948.0
#
#              money
# 0     5.088596e+08
# 1     1.820530e+08
# 2     6.118624e+07
# 3     2.400077e+08
# 4     7.471085e+08
# ...

# %%
new_codes[-1]
# Out:
# '300750.XSHE'
