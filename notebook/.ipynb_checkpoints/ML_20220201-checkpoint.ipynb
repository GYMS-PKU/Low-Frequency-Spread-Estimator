# %% [markdown]
# ## 使用ML方法组合估计器
# 2022-03-21
# - 更改目标为平均价差；加入平均收盘价这个特征
# 2022-04-16
# - 完善框架

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import importlib
import sys
sys.path.append('C:/Users/Administrator/Desktop/Repositories/Low-Frequency-Spread-Estimator')
sys.path.append('C:/Users/Handsome Bad Guy/Desktop/Repositories/Low-Frequency-Spread-Estimator')

from SpreadEstimator.SpreadEstimator import SpreadEstimator
from mytools.AutoTester import AutoTester

from time import time

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
import torch.optim as optim

from sklearn.linear_model import LinearRegression
from tqdm import tqdm

import sys
sys.path.append(r'C:\Users\Administrator\Desktop\Repositories\Low-Frequency-Spread-Estimator\notebook\tools')
from train_tools import *
from get_signal import *
from naive_model import *

# %%
import importlib
import train_tools
importlib.reload(train_tools)
from train_tools import *

# %%
se = SpreadEstimator()
univ = ~np.isnan(se.data.data_dic['close'])  # 合法的univ

# %%
class GateNet(nn.Module):
    def __init__(self, input_dim: int, output_dim: int, dropout: float = 0.7, alpha: float = 0.2):
        super(GateNet, self).__init__()
        self.input_dim = input_dim
        self.output_Dim = output_dim

        self.Dense1 = nn.Linear(input_dim, 16)
        self.Dense2 = nn.Linear(16, 8)
        self.Dense3 = nn.Linear(8, 8)
        self.Dense4 = nn.Linear(8, output_dim)

        self.gate0 = Gate(input_dim)
        self.gate1 = Gate(16)
        self.gate2 = Gate(8)
        self.gate3 = Gate(8)

        self.act = nn.LeakyReLU(alpha)

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = self.act(self.Dense1(self.gate0(self.dropout(x))))
        x = self.act(self.Dense2(self.gate1(self.dropout(x))))
        x = x + self.dropout(self.gate3(self.act(self.Dense3(self.gate2(self.dropout(x))))))
        x = self.Dense4(x)
        return x

# %% [markdown]
# ### 获得基本的训练数据

# %%
signal_spread = get_signal_spread(se)
# signal_spread[:,:, 3] /= 10
signal_spread[:,:, 3] = np.log(signal_spread[:,:, 3])
target_spread = get_target(se, 'spread')
signal_rela = get_signal_rela(se)
# signal_rela[:,:,3] /= 100
signal_rela[:,:, 3] = np.log(signal_rela[:,:, 3])
target_rela = get_target(se, 'relative_spread')
target_wrela = get_target(se, 'vol_wtd_rel_bas')
# Out:
# mean corr: -0.4630, positive_corr_ratio: 0.0000, corr_IR: -16.7947
# mean corr: 0.7924, positive_corr_ratio: 1.0000, corr_IR: 18.7505
# mean corr: -0.3688, positive_corr_ratio: 0.0000, corr_IR: -8.7364
# mean corr: -0.3920, positive_corr_ratio: 0.0000, corr_IR: -9.9100
# mean corr: -0.2082, positive_corr_ratio: 0.0000, corr_IR: -3.6871
# mean corr: 0.0994, positive_corr_ratio: 0.9279, corr_IR: 1.2409
# mean corr: -0.2317, positive_corr_ratio: 0.0000, corr_IR: -3.9265
# mean corr: -0.3920, positive_corr_ratio: 0.0000, corr_IR: -9.9100

# %%
x_train_cs_spread, y_train_cs_spread = get_train_data_cs(signal_spread, target_spread, univ)
x_train_cs_rela, y_train_cs_rela = get_train_data_cs(signal_rela, target_rela, univ)
x_train_cs_wrela, y_train_cs_wrela = get_train_data_cs(signal_rela, target_wrela, univ)

x_train_ts_spread, y_train_ts_spread = get_train_data_ts(signal_spread, target_spread, univ)
x_train_ts_rela, y_train_ts_rela = get_train_data_ts(signal_rela, target_rela, univ)
x_train_ts_wrela, y_train_ts_wrela = get_train_data_ts(signal_rela, target_wrela, univ)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 80/80 [00:00<00:00, 729.92it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 80/80 [00:00<00:00, 999.06it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 80/80 [00:00<00:00, 1141.82it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 800/800 [00:00<00:00, 1702.27it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 800/800 [00:00<00:00, 1442.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 800/800 [00:00<00:00, 1780.12it/s]

# %% [markdown]
# ### 使用截面相关系数作为损失函数，训练模型

# %%
# GateNet cs
device = 'cuda'
n = 4
# model = nn.Linear(n, 1).to(device)

loss_func = ICLoss()

print('spread cs')
gatenet_spread = GateNet(input_dim=n, output_dim=1, dropout=0.0, alpha=0.2).to(device)
optimizer = torch.optim.AdamW(gatenet_spread.parameters(), lr=2e-3, weight_decay=0)
train_cs(x_train_cs_spread, y_train_cs_spread, gatenet_spread, optimizer, loss_func, signal=signal_spread, 
         target=target_spread, univ=univ,
         vs_s=160, os_s=160, epochs=5, batch_size=1)
print()

print('relative spread cs')
gatenet_rela = GateNet(input_dim=n, output_dim=1, dropout=0.0, alpha=0.2).to(device)
optimizer = torch.optim.AdamW(gatenet_rela.parameters(), lr=1e-3, weight_decay=0)
train_cs(x_train_cs_rela, y_train_cs_rela, gatenet_rela, optimizer, loss_func, signal=signal_rela, 
         target=target_rela, univ=univ,
         vs_s=160, os_s=160, epochs=20, batch_size=1,verbose=2)
print()

print('w relative spread cs')
gatenet_wrela = GateNet(input_dim=n, output_dim=1, dropout=0.0, alpha=0.2).to(device)
optimizer = torch.optim.AdamW(gatenet_wrela.parameters(), lr=1e-3, weight_decay=0)
train_cs(x_train_cs_wrela, y_train_cs_wrela, gatenet_wrela, optimizer, loss_func, signal=signal_rela, 
         target=target_wrela, univ=univ,
         vs_s=160, os_s=160, epochs=20, batch_size=1,verbose=2)
# Out:
# spread cs
# epoch 1
# -0.7612964544869676
# vs cs IC: 0.8458
# os cs IC: 0.8018
# epoch 2
# -0.8454675380187698
# vs cs IC: 0.8307
# os cs IC: 0.7905
# epoch 3
# -0.8394640714307374
# vs cs IC: 0.8414
# os cs IC: 0.8009
# epoch 4
# -0.8475318686871589
# vs cs IC: 0.8401
# os cs IC: 0.7972
# epoch 5
# -0.8535497867608373
# vs cs IC: 0.8498
# os cs IC: 0.8075
#
# relative spread cs
# epoch 2
# -0.48109293179433854
# vs cs IC: 0.5400
# os cs IC: 0.5314
# epoch 4
# -0.6503469416352569
# vs cs IC: 0.6978
# os cs IC: 0.6910
# epoch 6
# -0.7443695488523264
# vs cs IC: 0.7581
# os cs IC: 0.7514
# epoch 8
# -0.7736758706999607
# vs cs IC: 0.8107
# os cs IC: 0.8044
# epoch 10
# -0.8439678442282755
# vs cs IC: 0.8342
# os cs IC: 0.8303
# epoch 12
# -0.8661347696038543
# vs cs IC: 0.8382
# os cs IC: 0.8376
# epoch 14
# -0.8823942151225981
# vs cs IC: 0.8643
# os cs IC: 0.8647
# epoch 16
# -0.9012433261167808
# vs cs IC: 0.8890
# os cs IC: 0.8883
# epoch 18
# -0.9193060065879196
# vs cs IC: 0.9212
# os cs IC: 0.9200
# epoch 20
# -0.9288480760621243
# vs cs IC: 0.9349
# os cs IC: 0.9341
#
# w relative spread cs
# epoch 2
# -0.5034809000179415
# vs cs IC: 0.5512
# os cs IC: 0.5392
# epoch 4
# -0.672639156951279
# vs cs IC: 0.6953
# os cs IC: 0.6860
# epoch 6
# -0.7634792923927307
# vs cs IC: 0.7669
# os cs IC: 0.7585
# epoch 8
# -0.8252871671661002
# vs cs IC: 0.8300
# os cs IC: 0.8229
# epoch 10
# -0.8675413952499139
# vs cs IC: 0.8592
# os cs IC: 0.8546
# epoch 12
# -0.8854306770152733
# vs cs IC: 0.8753
# os cs IC: 0.8701
# epoch 14
# -0.9066587921048774
# vs cs IC: 0.9022
# os cs IC: 0.8980
# epoch 16
# -0.9257180016548907
# vs cs IC: 0.9244
# os cs IC: 0.9235
# epoch 18
# -0.9378837454514425
# vs cs IC: 0.9313
# os cs IC: 0.9304
# epoch 20
# -0.9432653432986775
# vs cs IC: 0.9305
# os cs IC: 0.9328

# %%
# Linear cs
device = 'cuda'
n = 4

loss_func = ICLoss()

print('spread cs')
gatenet_spread = nn.Linear(n, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_spread.parameters(), lr=5e-4, weight_decay=0)
train_cs(x_train_cs_spread, y_train_cs_spread, gatenet_spread, optimizer, loss_func, signal=signal_spread, 
         target=target_spread, univ=univ,
         vs_s=160, os_s=160, epochs=5, batch_size=5)
print()

print('relative spread cs')
gatenet_rela = nn.Linear(n, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_rela.parameters(), lr=5e-4, weight_decay=0)
train_cs(x_train_cs_rela, y_train_cs_rela, gatenet_rela, optimizer, loss_func, signal=signal_rela, 
         target=target_rela, univ=univ,
         vs_s=160, os_s=160, epochs=10, batch_size=1)
print()

print('w relative spread cs')
gatenet_wrela = nn.Linear(n, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_wrela.parameters(), lr=5e-4, weight_decay=0)
train_cs(x_train_cs_wrela, y_train_cs_wrela, gatenet_wrela, optimizer, loss_func, signal=signal_rela, 
         target=target_wrela, univ=univ,
         vs_s=160, os_s=160, epochs=10, batch_size=1)
# Out:
# spread cs
# epoch 1
# -0.8692299761349642
# vs cs IC: 0.8370
# os cs IC: 0.8213
# epoch 2
# -0.8693157781528521
# vs cs IC: 0.8371
# os cs IC: 0.8213
# epoch 3
# -0.8694108452978013
# vs cs IC: 0.8371
# os cs IC: 0.8214
# epoch 4
# -0.8695111961304387
# vs cs IC: 0.8372
# os cs IC: 0.8214
# epoch 5
# -0.86962768171407
# vs cs IC: 0.8373
# os cs IC: 0.8215
#
# relative spread cs
# epoch 1
# 0.34182053540326374
# vs cs IC: -0.3554
# os cs IC: -0.3637
# epoch 2
# 0.34115358470361445
# vs cs IC: -0.3554
# os cs IC: -0.3637
# epoch 3
# 0.3378946822655352
# vs cs IC: -0.3554
# os cs IC: -0.3636
# epoch 4
# -0.24464179692153312
# vs cs IC: 0.3554
# os cs IC: 0.3638
# epoch 5
# -0.3458357144005691
# vs cs IC: 0.3554
# os cs IC: 0.3638
# epoch 6
# -0.3450097694427152
# vs cs IC: 0.3554
# os cs IC: 0.3638
# epoch 7
# -0.34465509464469135
# vs cs IC: 0.3554
# os cs IC: 0.3637
# epoch 8
# -0.34444737547560583
# vs cs IC: 0.3554
# os cs IC: 0.3637
# epoch 9
# -0.34430780139150496
# vs cs IC: 0.3554
# os cs IC: 0.3637
# epoch 10
# -0.34420628449584867
# vs cs IC: 0.3554
# os cs IC: 0.3637
#
# w relative spread cs
# epoch 1
# 0.35560756619972517
# vs cs IC: -0.3661
# os cs IC: -0.3720
# epoch 2
# 0.3549753925468348
# vs cs IC: -0.3661
# os cs IC: -0.3720
# epoch 3
# 0.35244334309915953
# vs cs IC: -0.3661
# os cs IC: -0.3721
# epoch 4
# -0.17166219316894496
# vs cs IC: 0.3660
# os cs IC: 0.3720
# epoch 5
# -0.3597128810007361
# vs cs IC: 0.3660
# os cs IC: 0.3720
# epoch 6
# -0.3587015678610983
# vs cs IC: 0.3660
# os cs IC: 0.3720
# epoch 7
# -0.3582972197593013
# vs cs IC: 0.3660
# os cs IC: 0.3720
# epoch 8
# -0.35806632570073577
# vs cs IC: 0.3660
# os cs IC: 0.3720
# epoch 9
# -0.3579132858710953
# vs cs IC: 0.3660
# os cs IC: 0.3720
# epoch 10
# -0.3578029267395599
# vs cs IC: 0.3660
# os cs IC: 0.3720

# %%
# GateNet时序
print('spread ts')
gatenet_spread_ts = GateNet(input_dim=n, output_dim=1, dropout=0.0, alpha=0.2).to(device)
optimizer = torch.optim.AdamW(gatenet_spread_ts.parameters(), lr=5e-4, weight_decay=0)
train_ts(x_train_ts_spread, y_train_ts_spread, gatenet_spread_ts, optimizer, loss_func, signal=signal_spread, 
         target=target_spread, univ=univ,
         vs_s=800, os_s=1400, epochs=5, batch_size=5)
print()

print('relative spread ts')
gatenet_rela_ts = GateNet(input_dim=n, output_dim=1, dropout=0.0, alpha=0.2).to(device)
optimizer = torch.optim.AdamW(gatenet_rela_ts.parameters(), lr=1e-4, weight_decay=0)
train_ts(x_train_ts_rela, y_train_ts_rela, gatenet_rela_ts, optimizer, loss_func, signal=signal_rela, 
         target=target_rela, univ=univ,
         vs_s=800, os_s=1400, epochs=10, batch_size=3)
print()

print('w relative spread ts')
gatenet_wrela_ts = GateNet(input_dim=n, output_dim=1, dropout=0.0, alpha=0.2).to(device)
optimizer = torch.optim.AdamW(gatenet_wrela_ts.parameters(), lr=1e-4, weight_decay=0)
train_ts(x_train_ts_wrela, y_train_ts_wrela, gatenet_wrela_ts, optimizer, loss_func, signal=signal_rela, 
         target=target_wrela, univ=univ,
         vs_s=800, os_s=1400, epochs=10, batch_size=3)
# Out:
# spread ts
# epoch 1
# vs ts IC: 0.4641
# os ts IC: 0.5942
# epoch 2
# vs ts IC: 0.4793
# os ts IC: 0.6143
# epoch 3
# vs ts IC: 0.4917
# os ts IC: 0.6291
# epoch 4
# vs ts IC: 0.4999
# os ts IC: 0.6352
# epoch 5
# vs ts IC: 0.5165
# os ts IC: 0.6507
#
# relative spread ts
# epoch 1
# vs ts IC: 0.5301
# os ts IC: 0.3895
# epoch 2
# vs ts IC: 0.4814
# os ts IC: 0.3443
# epoch 3
# vs ts IC: 0.5014
# os ts IC: 0.3684
# epoch 4
# vs ts IC: 0.5474
# os ts IC: 0.4273
# epoch 5
# vs ts IC: 0.6328
# os ts IC: 0.5388
# epoch 6
# vs ts IC: 0.6352
# os ts IC: 0.5491
# epoch 7
# vs ts IC: 0.5681
# os ts IC: 0.4844
# epoch 8
# vs ts IC: 0.6241
# os ts IC: 0.5429
# epoch 9
# vs ts IC: 0.6286
# os ts IC: 0.5519
# epoch 10
# vs ts IC: 0.6381
# os ts IC: 0.5500
#
# w relative spread ts
# epoch 1
# vs ts IC: 0.6019
# os ts IC: 0.5048
# epoch 2
# vs ts IC: 0.6119
# os ts IC: 0.5166
# epoch 3
# vs ts IC: 0.4932
# os ts IC: 0.3519
# epoch 4
# vs ts IC: 0.6138
# os ts IC: 0.5352
# epoch 5
# vs ts IC: 0.5485
# os ts IC: 0.4435
# epoch 6
# vs ts IC: 0.5978
# os ts IC: 0.5195
# epoch 7
# vs ts IC: 0.5003
# os ts IC: 0.3724
# epoch 8
# vs ts IC: 0.5898
# os ts IC: 0.4899
# epoch 9
# vs ts IC: 0.5941
# os ts IC: 0.5101
# epoch 10
# vs ts IC: 0.5987
# os ts IC: 0.5104

# %%
# Linear时序
print('spread ts')
gatenet_spread_ts = nn.Linear(n, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_spread_ts.parameters(), lr=5e-4, weight_decay=0)
train_ts(x_train_ts_spread, y_train_ts_spread, gatenet_spread_ts, optimizer, loss_func, signal=signal_spread, 
         target=target_spread, univ=univ,
         vs_s=800, os_s=1400, epochs=5, batch_size=5)
print()

print('relative spread ts')
gatenet_rela_ts = nn.Linear(n, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_rela_ts.parameters(), lr=5e-4, weight_decay=0)
train_ts(x_train_ts_rela, y_train_ts_rela, gatenet_rela_ts, optimizer, loss_func, signal=signal_rela, 
         target=target_rela, univ=univ,
         vs_s=800, os_s=1400, epochs=10, batch_size=1)
print()

print('w relative spread ts')
gatenet_wrela_ts = nn.Linear(n, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_wrela_ts.parameters(), lr=5e-4, weight_decay=0)
train_ts(x_train_ts_wrela, y_train_ts_wrela, gatenet_wrela_ts, optimizer, loss_func, signal=signal_rela, 
         target=target_wrela, univ=univ,
         vs_s=800, os_s=1400, epochs=10, batch_size=1)
# Out:
# spread ts
# epoch 1
# vs ts IC: 0.4690
# os ts IC: 0.6302
# epoch 2
# vs ts IC: 0.5244
# os ts IC: 0.6749
# epoch 3
# vs ts IC: 0.5001
# os ts IC: 0.6580
# epoch 4
# vs ts IC: 0.4944
# os ts IC: 0.6533
# epoch 5
# vs ts IC: 0.4934
# os ts IC: 0.6525
#
# relative spread ts
# epoch 1
# vs ts IC: 0.6431
# os ts IC: 0.5098
# epoch 2
# vs ts IC: 0.6432
# os ts IC: 0.5100
# epoch 3
# vs ts IC: 0.6435
# os ts IC: 0.5103
# epoch 4
# vs ts IC: 0.6437
# os ts IC: 0.5104
# epoch 5
# vs ts IC: 0.6438
# os ts IC: 0.5105
# epoch 6
# vs ts IC: 0.6439
# os ts IC: 0.5105
# epoch 7
# vs ts IC: 0.6439
# os ts IC: 0.5105
# epoch 8
# vs ts IC: 0.6439
# os ts IC: 0.5105
# epoch 9
# vs ts IC: 0.6439
# os ts IC: 0.5106
# epoch 10
# vs ts IC: 0.6439
# os ts IC: 0.5106
#
# w relative spread ts
# epoch 1
# vs ts IC: 0.5792
# os ts IC: 0.4338
# epoch 2
# vs ts IC: 0.5792
# os ts IC: 0.4338
# epoch 3
# vs ts IC: 0.5792
# os ts IC: 0.4338
# epoch 4
# vs ts IC: 0.5791
# os ts IC: 0.4338
# epoch 5
# vs ts IC: 0.5791
# os ts IC: 0.4337
# epoch 6
# vs ts IC: 0.5790
# os ts IC: 0.4337
# epoch 7
# vs ts IC: 0.5790
# os ts IC: 0.4337
# epoch 8
# vs ts IC: 0.5789
# os ts IC: 0.4336
# epoch 9
# vs ts IC: 0.5789
# os ts IC: 0.4336
# epoch 10
# vs ts IC: 0.5789
# os ts IC: 0.4336

# %% [markdown]
# ### 测试以MSE为损失函数

# %%
# GateNet cs
device = 'cuda'
n = 4
# model = nn.Linear(n, 1).to(device)

loss_func = MSELoss()

# print('spread cs')
# gatenet_spread = GateNet(input_dim=n, output_dim=1, dropout=0.0, alpha=0.2).to(device)
# optimizer = torch.optim.AdamW(gatenet_spread.parameters(), lr=1e-4, weight_decay=0)
# train_cs(x_train_cs_spread, y_train_cs_spread, gatenet_spread, optimizer, loss_func, signal=signal_spread, 
#          target=target_spread, univ=univ,
#          vs_s=160, os_s=160, epochs=30, batch_size=2, verbose=3)
# print()

# print('relative spread cs')
# gatenet_rela = GateNet(input_dim=n, output_dim=1, dropout=0.0, alpha=0.2).to(device)
# optimizer = torch.optim.AdamW(gatenet_rela.parameters(), lr=2e-4, weight_decay=0)
# train_cs(x_train_cs_rela, y_train_cs_rela, gatenet_rela, optimizer, loss_func, signal=signal_rela, 
#          target=target_rela, univ=univ,
#          vs_s=160, os_s=160, epochs=10, batch_size=1)
# print()

print('w relative spread cs')
gatenet_wrela = GateNet(input_dim=n, output_dim=1, dropout=0.0, alpha=0.2).to(device)
optimizer = torch.optim.AdamW(gatenet_wrela.parameters(), lr=2e-4, weight_decay=0)
train_cs(x_train_cs_wrela, y_train_cs_wrela, gatenet_wrela, optimizer, loss_func, signal=signal_rela, 
         target=target_wrela, univ=univ,
         vs_s=160, os_s=160, epochs=10, batch_size=1)
# Out:
# w relative spread cs
# epoch 1
# 0.03464733100816852
# vs cs IC: -0.3682
# os cs IC: -0.3802
# epoch 2
# 0.011475663189394553
# vs cs IC: -0.3515
# os cs IC: -0.3719
# epoch 3
# 0.0009024948621729101
# vs cs IC: -0.3421
# os cs IC: -0.3675
# epoch 4
# 0.004671207729337707
# vs cs IC: -0.3380
# os cs IC: -0.3649
# epoch 5
# 0.014638156019395492
# vs cs IC: -0.3491
# os cs IC: -0.3731
# epoch 6
# 0.015234879431788062
# vs cs IC: -0.3491
# os cs IC: -0.3731
# epoch 7
# 0.007085035402388846
# vs cs IC: -0.3502
# os cs IC: -0.3732
# epoch 8
# 0.0013195753916258328
# vs cs IC: -0.3529
# os cs IC: -0.3735
# epoch 9
# 0.0001839653646632795
# vs cs IC: -0.3571
# os cs IC: -0.3756
# epoch 10
# 0.00167929668448957
# vs cs IC: -0.3544
# os cs IC: -0.3739

# %%
# Linear
device = 'cuda'
n = 4

loss_func = MSELoss()

print('spread cs')
gatenet_spread = nn.Linear(n, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_spread.parameters(), lr=5e-4, weight_decay=0)
train_cs(x_train_cs_spread, y_train_cs_spread, gatenet_spread, optimizer, loss_func, signal=signal_spread, 
         target=target_spread, univ=univ,
         vs_s=160, os_s=160, epochs=5, batch_size=5)
print()

print('relative spread cs')
gatenet_rela = nn.Linear(n, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_rela.parameters(), lr=5e-4, weight_decay=0)
train_cs(x_train_cs_rela, y_train_cs_rela, gatenet_rela, optimizer, loss_func, signal=signal_rela, 
         target=target_rela, univ=univ,
         vs_s=160, os_s=160, epochs=10, batch_size=1)
print()

print('w relative spread cs')
gatenet_wrela = nn.Linear(n, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_wrela.parameters(), lr=5e-4, weight_decay=0)
train_cs(x_train_cs_wrela, y_train_cs_wrela, gatenet_wrela, optimizer, loss_func, signal=signal_rela, 
         target=target_wrela, univ=univ,
         vs_s=160, os_s=160, epochs=10, batch_size=1)
# Out:
# spread cs
# epoch 1
# 34.803288375275045
# vs cs IC: 0.8369
# os cs IC: 0.8212
# epoch 2
# 31.99899523771262
# vs cs IC: 0.8368
# os cs IC: 0.8212
# epoch 3
# 28.91506301300435
# vs cs IC: 0.8367
# os cs IC: 0.8211
# epoch 4
# 25.73801431776602
# vs cs IC: 0.8365
# os cs IC: 0.8210
# epoch 5
# 22.609138585344144
# vs cs IC: 0.8363
# os cs IC: 0.8209
#
# relative spread cs
# epoch 1
# 28.79224893111217
# vs cs IC: -0.3554
# os cs IC: -0.3637
# epoch 2
# 14.318454404420491
# vs cs IC: -0.3554
# os cs IC: -0.3637
# epoch 3
# 4.734122089192837
# vs cs IC: -0.3554
# os cs IC: -0.3636
# epoch 4
# 0.7198645431029645
# vs cs IC: -0.3553
# os cs IC: -0.3633
# epoch 5
# 1.390486017435412
# vs cs IC: 0.3554
# os cs IC: 0.3639
# epoch 6
# 5.3533087833018245
# vs cs IC: 0.3554
# os cs IC: 0.3638
# epoch 7
# 10.784465246562716
# vs cs IC: 0.3554
# os cs IC: 0.3638
# epoch 8
# 15.459841366055645
# vs cs IC: 0.3554
# os cs IC: 0.3638
# epoch 9
# 17.08352226547048
# vs cs IC: 0.3554
# os cs IC: 0.3638
# epoch 10
# 14.347513657581958
# vs cs IC: 0.3554
# os cs IC: 0.3638
#
# w relative spread cs
# epoch 1
# 28.792364168770707
# vs cs IC: -0.3661
# os cs IC: -0.3720
# epoch 2
# 14.3185396194458
# vs cs IC: -0.3661
# os cs IC: -0.3720
# epoch 3
# 4.734174031245558
# vs cs IC: -0.3661
# os cs IC: -0.3720
# epoch 4
# 0.7198841873603531
# vs cs IC: -0.3662
# os cs IC: -0.3718
# epoch 5
# 1.3904790369015705
# vs cs IC: 0.3660
# os cs IC: 0.3721
# epoch 6
# 5.353289700761626
# vs cs IC: 0.3660
# os cs IC: 0.3720
# epoch 7
# 10.784449788588512
# vs cs IC: 0.3660
# os cs IC: 0.3720
# epoch 8
# 15.459859341005735
# vs cs IC: 0.3660
# os cs IC: 0.3720
# epoch 9
# 17.083592390712305
# vs cs IC: 0.3660
# os cs IC: 0.3720
# epoch 10
# 14.347641087785552
# vs cs IC: 0.3660
# os cs IC: 0.3720

# %%
# GateNet时序
print('spread ts')
loss_func = MSELoss()

gatenet_spread_ts = GateNet(input_dim=n, output_dim=1, dropout=0.0, alpha=0.2).to(device)
optimizer = torch.optim.AdamW(gatenet_spread_ts.parameters(), lr=2e-5, weight_decay=0)
train_ts(x_train_ts_spread, y_train_ts_spread, gatenet_spread_ts, optimizer, loss_func, signal=signal_spread, 
         target=target_spread, univ=univ,
         vs_s=800, os_s=1400, epochs=10, batch_size=2)
print()

# print('relative spread ts')
# gatenet_rela_ts = GateNet(input_dim=n, output_dim=1, dropout=0.0, alpha=0.2).to(device)
# optimizer = torch.optim.AdamW(gatenet_rela_ts.parameters(), lr=2e-5, weight_decay=0)
# train_ts(x_train_ts_rela, y_train_ts_rela, gatenet_rela_ts, optimizer, loss_func, signal=signal_rela, 
#          target=target_rela, univ=univ,
#          vs_s=800, os_s=1400, epochs=10, batch_size=2)
# print()

# print('w relative spread ts')
# gatenet_wrela_ts = GateNet(input_dim=n, output_dim=1, dropout=0.0, alpha=0.2).to(device)
# optimizer = torch.optim.AdamW(gatenet_wrela_ts.parameters(), lr=2e-5, weight_decay=0)
# train_ts(x_train_ts_wrela, y_train_ts_wrela, gatenet_wrela_ts, optimizer, loss_func, signal=signal_rela, 
#          target=target_wrela, univ=univ,
#          vs_s=800, os_s=1400, epochs=10, batch_size=2)
# Out:
# spread ts
# epoch 1
# vs ts IC: -0.4197
# os ts IC: -0.5701
# epoch 2
# vs ts IC: -0.2606
# os ts IC: -0.4361
# epoch 3
# vs ts IC: -0.1429
# os ts IC: -0.2310
# epoch 4
# vs ts IC: 0.1755
# os ts IC: 0.3137
# epoch 5
# vs ts IC: 0.2236
# os ts IC: 0.3809
# epoch 6
# vs ts IC: 0.2302
# os ts IC: 0.3910
# epoch 7
# vs ts IC: 0.2321
# os ts IC: 0.3956
# epoch 8
# vs ts IC: 0.2152
# os ts IC: 0.3769
# epoch 9
# vs ts IC: 0.1835
# os ts IC: 0.3383
# epoch 10
# vs ts IC: 0.1247
# os ts IC: 0.2567

# %%
# Linear时序
print('spread ts')
gatenet_spread_ts = nn.Linear(n, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_spread_ts.parameters(), lr=2e-5, weight_decay=0)
train_ts(x_train_ts_spread, y_train_ts_spread, gatenet_spread_ts, optimizer, loss_func, signal=signal_spread, 
         target=target_spread, univ=univ,
         vs_s=800, os_s=1400, epochs=5, batch_size=5)
print()

print('relative spread ts')
gatenet_rela_ts = nn.Linear(n, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_rela_ts.parameters(), lr=5e-5, weight_decay=0)
train_ts(x_train_ts_rela, y_train_ts_rela, gatenet_rela_ts, optimizer, loss_func, signal=signal_rela, 
         target=target_rela, univ=univ,
         vs_s=800, os_s=1400, epochs=10, batch_size=1)
print()

print('w relative spread ts')
gatenet_wrela_ts = nn.Linear(n, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_wrela_ts.parameters(), lr=5e-5, weight_decay=0)
train_ts(x_train_ts_wrela, y_train_ts_wrela, gatenet_wrela_ts, optimizer, loss_func, signal=signal_rela, 
         target=target_wrela, univ=univ,
         vs_s=800, os_s=1400, epochs=10, batch_size=1)
# Out:
# spread ts
# epoch 1
# vs ts IC: 0.4578
# os ts IC: 0.6192
# epoch 2
# vs ts IC: 0.4572
# os ts IC: 0.6187
# epoch 3
# vs ts IC: 0.4566
# os ts IC: 0.6181
# epoch 4
# vs ts IC: 0.4559
# os ts IC: 0.6174
# epoch 5
# vs ts IC: 0.4553
# os ts IC: 0.6167
#
# relative spread ts
# epoch 1
# vs ts IC: -0.6429
# os ts IC: -0.5098
# epoch 2
# vs ts IC: -0.6438
# os ts IC: -0.5106
# epoch 3
# vs ts IC: -0.6456
# os ts IC: -0.5123
# epoch 4
# vs ts IC: -0.6433
# os ts IC: -0.5173
# epoch 5
# vs ts IC: 0.6109
# os ts IC: 0.4904
# epoch 6
# vs ts IC: 0.6318
# os ts IC: 0.5021
# epoch 7
# vs ts IC: 0.6353
# os ts IC: 0.5043
# epoch 8
# vs ts IC: 0.6366
# os ts IC: 0.5051
# epoch 9
# vs ts IC: 0.6370
# os ts IC: 0.5054
# epoch 10
# vs ts IC: 0.6366
# os ts IC: 0.5051
#
# w relative spread ts
# epoch 1
# vs ts IC: -0.5766
# os ts IC: -0.4320
# epoch 2
# vs ts IC: -0.5784
# os ts IC: -0.4332
# epoch 3
# vs ts IC: -0.5822
# os ts IC: -0.4360
# epoch 4
# vs ts IC: -0.5916
# os ts IC: -0.4469
# epoch 5
# vs ts IC: 0.5311
# os ts IC: 0.4054
# epoch 6
# vs ts IC: 0.5591
# os ts IC: 0.4210
# epoch 7
# vs ts IC: 0.5642
# os ts IC: 0.4240
# epoch 8
# vs ts IC: 0.5661
# os ts IC: 0.4252
# epoch 9
# vs ts IC: 0.5668
# os ts IC: 0.4257
# epoch 10
# vs ts IC: 0.5661
# os ts IC: 0.4252

# %% [markdown]
# ## 分段线性模型

# %%
class MultiLinear(nn.Module):
    def __init__(self, input_dim: int, output_dim: int):
        super(MultiLinear, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim

        self.Dense = nn.ModuleList([nn.Linear(input_dim, output_dim) for i in range(4)])

    def forward(self, x):
        close = x[:,-1]
        y = self.Dense[0](x)
        y[(5<=close) & (close<10)] = self.Dense[1](x[(5<=close) & (close<10)])
        y[(10<=close) & (close<25)] = self.Dense[2](x[(10<=close) & (close<25)])
        y[close>25] = self.Dense[3](x[close>25])
        return y

# %%
# MultiLinear cs
device = 'cuda'
n = 4
# model = nn.Linear(n, 1).to(device)

loss_func = ICLoss()

print('spread cs')
gatenet_spread = MultiLinear(4, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_spread.parameters(), lr=5e-4, weight_decay=1e-1)
train_cs(x_train_cs_spread, y_train_cs_spread, gatenet_spread, optimizer, loss_func, signal=signal_spread, 
         target=target_spread, univ=univ,
         vs_s=160, os_s=160, epochs=5, batch_size=1)
print()

print('relative spread cs')
gatenet_rela = MultiLinear(4, 1).to(device).to(device)
optimizer = torch.optim.AdamW(gatenet_rela.parameters(), lr=5e-4, weight_decay=0)
train_cs(x_train_cs_rela, y_train_cs_rela, gatenet_rela, optimizer, loss_func, signal=signal_rela, 
         target=target_rela, univ=univ,
         vs_s=160, os_s=160, epochs=10, batch_size=1)
print()

print('w relative spread cs')
gatenet_wrela = MultiLinear(4, 1).to(device).to(device)
optimizer = torch.optim.AdamW(gatenet_wrela.parameters(), lr=5e-4, weight_decay=0)
train_cs(x_train_cs_wrela, y_train_cs_wrela, gatenet_wrela, optimizer, loss_func, signal=signal_rela, 
         target=target_wrela, univ=univ,
         vs_s=160, os_s=160, epochs=10, batch_size=1)
# Out:
# spread cs
# epoch 1
# -0.8266964215266553
# vs cs IC: 0.8072
# os cs IC: 0.7909
# epoch 2
# -0.839894759504101
# vs cs IC: 0.8173
# os cs IC: 0.8012
# epoch 3
# -0.8486995802649969
# vs cs IC: 0.8238
# os cs IC: 0.8078
# epoch 4
# -0.8541653465621079
# vs cs IC: 0.8279
# os cs IC: 0.8120
# epoch 5
# -0.8575590864012513
# vs cs IC: 0.8305
# os cs IC: 0.8147
#
# relative spread cs
# epoch 1
# 0.14085172918401187
# vs cs IC: -0.1514
# os cs IC: -0.1580
# epoch 2
# 0.09182325316758096
# vs cs IC: -0.1006
# os cs IC: -0.1059
# epoch 3
# 0.015942659476975308
# vs cs IC: -0.0234
# os cs IC: -0.0269
# epoch 4
# -0.10167045952587188
# vs cs IC: 0.0983
# os cs IC: 0.0975
# epoch 5
# -0.27975391643711284
# vs cs IC: 0.2852
# os cs IC: 0.2870
# epoch 6
# -0.4881780060786235
# vs cs IC: 0.4973
# os cs IC: 0.4988
# epoch 7
# -0.6179198833960521
# vs cs IC: 0.6156
# os cs IC: 0.6162
# epoch 8
# -0.648147343080255
# vs cs IC: 0.6394
# os cs IC: 0.6415
# epoch 9
# -0.6389376445661618
# vs cs IC: 0.6305
# os cs IC: 0.6345
# epoch 10
# -0.6229915105843846
# vs cs IC: 0.6162
# os cs IC: 0.6216
#
# w relative spread cs
# epoch 1
# 0.15155747155599955
# vs cs IC: -0.1622
# os cs IC: -0.1667
# epoch 2
# 0.10176292731414867
# vs cs IC: -0.1112
# os cs IC: -0.1145
# epoch 3
# 0.024616856043613102
# vs cs IC: -0.0337
# os cs IC: -0.0353
# epoch 4
# -0.09518668833601324
# vs cs IC: 0.0889
# os cs IC: 0.0897
# epoch 5
# -0.277182262720941
# vs cs IC: 0.2779
# os cs IC: 0.2809
# epoch 6
# -0.49143297913708267
# vs cs IC: 0.4942
# os cs IC: 0.4958
# epoch 7
# -0.6264327447625655
# vs cs IC: 0.6168
# os cs IC: 0.6166
# epoch 8
# -0.6594306751142575
# vs cs IC: 0.6434
# os cs IC: 0.6442
# epoch 9
# -0.6512688662432418
# vs cs IC: 0.6358
# os cs IC: 0.6383
# epoch 10
# -0.6356065265740021
# vs cs IC: 0.6222
# os cs IC: 0.6259

# %%
gatenet_spread_ts = MultiLinear(4, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_spread_ts.parameters(), lr=5e-4, weight_decay=0)
train_ts(x_train_ts_spread, y_train_ts_spread, gatenet_spread_ts, optimizer, loss_func, signal=signal_spread, 
         target=target_spread, univ=univ,
         vs_s=800, os_s=1400, epochs=5, batch_size=5)
print()

print('relative spread ts')
gatenet_rela_ts = MultiLinear(4, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_rela_ts.parameters(), lr=1e-4, weight_decay=0)
train_ts(x_train_ts_rela, y_train_ts_rela, gatenet_rela_ts, optimizer, loss_func, signal=signal_rela, 
         target=target_rela, univ=univ,
         vs_s=800, os_s=1400, epochs=10, batch_size=3)
print()

print('w relative spread ts')
gatenet_wrela_ts = MultiLinear(4, 1).to(device)
optimizer = torch.optim.AdamW(gatenet_wrela_ts.parameters(), lr=1e-4, weight_decay=0)
train_ts(x_train_ts_wrela, y_train_ts_wrela, gatenet_wrela_ts, optimizer, loss_func, signal=signal_rela, 
         target=target_wrela, univ=univ,
         vs_s=800, os_s=1400, epochs=10, batch_size=3)
# Out:
# epoch 1
# vs ts IC: 0.1861
# os ts IC: 0.1705
# epoch 2
# vs ts IC: 0.3483
# os ts IC: 0.4641
# epoch 3
# vs ts IC: 0.4520
# os ts IC: 0.6151
# epoch 4
# vs ts IC: 0.4654
# os ts IC: 0.6249
# epoch 5
# vs ts IC: 0.4718
# os ts IC: 0.6288
#
# relative spread ts
# epoch 1
# vs ts IC: -0.0093
# os ts IC: 0.1228
# epoch 2
# vs ts IC: 0.2845
# os ts IC: 0.2907
# epoch 3
# vs ts IC: 0.2989
# os ts IC: 0.3016
# epoch 4
# vs ts IC: 0.3053
# os ts IC: 0.3077
# epoch 5
# vs ts IC: 0.3159
# os ts IC: 0.3164
# epoch 6
# vs ts IC: 0.3276
# os ts IC: 0.3260
# epoch 7
# vs ts IC: 0.3271
# os ts IC: 0.3274
# epoch 8
# vs ts IC: 0.3304
# os ts IC: 0.3313
# epoch 9
# vs ts IC: 0.3353
# os ts IC: 0.3369
# epoch 10
# vs ts IC: 0.3504
# os ts IC: 0.3380
#
# w relative spread ts
# epoch 1
# vs ts IC: -0.0046
# os ts IC: 0.1018
# epoch 2
# vs ts IC: 0.2613
# os ts IC: 0.2567
# epoch 3
# vs ts IC: 0.2652
# os ts IC: 0.2623
# epoch 4
# vs ts IC: 0.2760
# os ts IC: 0.2715
# epoch 5
# vs ts IC: 0.2857
# os ts IC: 0.2800
# epoch 6
# vs ts IC: 0.2846
# os ts IC: 0.2805
# epoch 7
# vs ts IC: 0.2877
# os ts IC: 0.2839
# epoch 8
# vs ts IC: 0.2919
# os ts IC: 0.2884
# epoch 9
# vs ts IC: 0.2949
# os ts IC: 0.2924
# epoch 10
# vs ts IC: 0.3061
# os ts IC: 0.2822

# %%
# MultiLinear cs MSE
device = 'cuda'
n = 4
# model = nn.Linear(n, 1).to(device)

loss_func = MSELoss()

# print('spread cs')
# gatenet_spread = MultiLinear(4, 1).to(device)
# optimizer = torch.optim.AdamW(gatenet_spread.parameters(), lr=1e-4, weight_decay=1e-1)
# train_cs(x_train_cs_spread, y_train_cs_spread, gatenet_spread, optimizer, loss_func, signal=signal_spread, 
#          target=target_spread, univ=univ,
#          vs_s=160, os_s=160, epochs=5, batch_size=1)
# print()

print('relative spread cs')
gatenet_rela = MultiLinear(4, 1).to(device).to(device)
optimizer = torch.optim.AdamW(gatenet_rela.parameters(), lr=5e-4, weight_decay=0)
train_cs(x_train_cs_rela[:1], y_train_cs_rela[:1], gatenet_rela, optimizer, loss_func, signal=signal_rela, 
         target=target_rela, univ=univ,
         vs_s=160, os_s=160, epochs=1000, batch_size=1, verbose=100)

print()

# print('w relative spread cs')
# gatenet_wrela = MultiLinear(4, 1).to(device).to(device)
# optimizer = torch.optim.AdamW(gatenet_wrela.parameters(), lr=1e-4, weight_decay=0)
# train_cs(x_train_cs_wrela, y_train_cs_wrela, gatenet_wrela, optimizer, loss_func, signal=signal_rela, 
#          target=target_wrela, univ=univ,
#          vs_s=160, os_s=160, epochs=20, batch_size=1, verbose=2)
# Out:
# relative spread cs
# epoch 100
# 0.15951183438301086
# vs cs IC: -0.3593
# os cs IC: -0.3740
# epoch 200
# 0.10142172127962112
# vs cs IC: -0.3552
# os cs IC: -0.3735
# epoch 300
# 0.056844159960746765
# vs cs IC: -0.3509
# os cs IC: -0.3718
# epoch 400
# 0.02594456635415554
# vs cs IC: -0.3472
# os cs IC: -0.3701
# epoch 500
# 0.0076579018495976925
# vs cs IC: -0.3442
# os cs IC: -0.3685
# epoch 600
# 0.0005319276824593544
# vs cs IC: -0.3418
# os cs IC: -0.3672
# epoch 700
# 0.002887980081140995
# vs cs IC: -0.3398
# os cs IC: -0.3661
# epoch 800
# 0.012844540178775787
# vs cs IC: -0.3382
# os cs IC: -0.3651
# epoch 900
# 0.02829509787261486
# vs cs IC: -0.3368
# os cs IC: -0.3644
# epoch 1000
# 0.04686815291643143
# vs cs IC: -0.3357
# os cs IC: -0.3637

# %%
gatenet_rela(x_train_cs_rela[0])
# Out:
# tensor([[0.2067],
#         [0.2226],
#         [0.2604],
#         ...,
#         [0.2334],
#         [0.2168],
#         [0.3453]], device='cuda:0', grad_fn=<IndexPutBackward>)

# %%
x_train_cs_rela[0]
# Out:
# tensor([[0.0067, 0.0021, 0.0073, 0.0150],
#         [0.0075, 0.0021, 0.0111, 0.0299],
#         [0.0189, 0.0025, 0.0570, 0.0320],
#         ...,
#         [0.0115, 0.0017, 0.0178, 0.0341],
#         [0.0108, 0.0025, 0.0231, 0.0121],
#         [0.0186, 0.0052, 0.0174, 0.1531]], device='cuda:0')

# %%
y_train_cs_rela[0]
# Out:
# tensor([[0.0007],
#         [0.0005],
#         [0.0013],
#         ...,
#         [0.0004],
#         [0.0012],
#         [0.0003]], device='cuda:0')

# %%
gatenet_rela.Dense[3].weight
# Out:
# Parameter containing:
# tensor([[-0.0450,  0.0725, -0.0020,  0.4371]], device='cuda:0',
#        requires_grad=True)

# %%
loss_func = MSELoss()
gatenet_spread_ts = MultiLinear(4, 1).to(device).to(device)
optimizer = torch.optim.AdamW(gatenet_spread_ts.parameters(), lr=2e-4, weight_decay=0)
train_ts(x_train_ts_spread, y_train_ts_spread, gatenet_spread_ts, optimizer, loss_func, signal=signal_spread, 
         target=target_spread, univ=univ,
         vs_s=800, os_s=1400, epochs=5, batch_size=5)
print()

print('relative spread ts')
gatenet_rela_ts = MultiLinear(4, 1).to(device).to(device)
optimizer = torch.optim.AdamW(gatenet_rela_ts.parameters(), lr=5e-5, weight_decay=0)
train_ts(x_train_ts_rela, y_train_ts_rela, gatenet_rela_ts, optimizer, loss_func, signal=signal_rela, 
         target=target_rela, univ=univ,
         vs_s=800, os_s=1400, epochs=10, batch_size=3)
print()

print('w relative spread ts')
gatenet_wrela_ts = MultiLinear(4, 1).to(device).to(device)
optimizer = torch.optim.AdamW(gatenet_wrela_ts.parameters(), lr=5e-5, weight_decay=0)
train_ts(x_train_ts_wrela, y_train_ts_wrela, gatenet_wrela_ts, optimizer, loss_func, signal=signal_rela, 
         target=target_wrela, univ=univ,
         vs_s=800, os_s=1400, epochs=10, batch_size=3)
# Out:
# epoch 1
# vs ts IC: 0.0788
# os ts IC: 0.0279
# epoch 2
# vs ts IC: 0.0220
# os ts IC: -0.0254
# epoch 3
# vs ts IC: 0.0711
# os ts IC: 0.0959
# epoch 4
# vs ts IC: 0.4124
# os ts IC: 0.5560
# epoch 5
# vs ts IC: 0.4492
# os ts IC: 0.6047
#
# relative spread ts
# epoch 1
# vs ts IC: -0.0441
# os ts IC: 0.0872
# epoch 2
# vs ts IC: -0.0296
# os ts IC: 0.1018
# epoch 3
# vs ts IC: -0.0115
# os ts IC: 0.1152
# epoch 4
# vs ts IC: 0.2472
# os ts IC: 0.2610
# epoch 5
# vs ts IC: 0.2846
# os ts IC: 0.2849
# epoch 6
# vs ts IC: 0.2934
# os ts IC: 0.2918
# epoch 7
# vs ts IC: 0.3012
# os ts IC: 0.2966
# epoch 8
# vs ts IC: 0.2906
# os ts IC: 0.2826
# epoch 9
# vs ts IC: 0.0209
# os ts IC: 0.0627
# epoch 10
# vs ts IC: -0.2877
# os ts IC: -0.1302
#
# w relative spread ts
# epoch 1
# vs ts IC: -0.0401
# os ts IC: 0.0668
# epoch 2
# vs ts IC: -0.0252
# os ts IC: 0.0813
# epoch 3
# vs ts IC: -0.0048
# os ts IC: 0.0954
# epoch 4
# vs ts IC: 0.2359
# os ts IC: 0.2345
# epoch 5
# vs ts IC: 0.2535
# os ts IC: 0.2482
# epoch 6
# vs ts IC: 0.2595
# os ts IC: 0.2537
# epoch 7
# vs ts IC: 0.2662
# os ts IC: 0.2579
# epoch 8
# vs ts IC: 0.2585
# os ts IC: 0.2463
# epoch 9
# vs ts IC: 0.0430
# os ts IC: 0.0589
# epoch 10
# vs ts IC: -0.2568
# os ts IC: -0.1247

# %%
torch.cuda.empty_cache()

# %% [markdown]
# ## 绘制预测和实际的散点图

# %%
# GateNet cs

xx = []
yy = []

for i in range(10):
    xx += list(model(x_test[i]).detach().cpu().numpy()[:,0])
    yy += list(y_test[i].cpu().numpy()[:,0])
    
plt.scatter(yy, xx)
plt.show()
# print(np.mean((np.array(xx)-np.array(yy))**2))

# %%
# linear cs

xx = []
yy = []
for i in range(1):
    xx += list(model(x_test[i]).detach().cpu().numpy()[:,0])
    yy += list(y_test[i].cpu().numpy()[:,0])
plt.scatter(yy, xx)
plt.show()

# %%
# multilinear cs

xx = []
yy = []
for i in range(1):
    xx += list(model(x_test[i]).detach().cpu().numpy()[:,0])
    yy += list(y_test[i].cpu().numpy()[:,0])
plt.scatter(yy, xx)
plt.show()
print(np.corrcoef(xx,yy)[0,1])
# Out:
# 0.7001803088326078

# %% [markdown]
# #### 查看线性函数的参数

# %%
model.weight
# Out:
# Parameter containing:
# tensor([[-3.0066e-02, -8.4163e-02,  6.1020e-03, -1.4581e-05]], device='cuda:0',
#        requires_grad=True)

# %% [markdown]
# ## 置换特征重要性
# 我们将使用置换特征重要性(Permutation Feature Importance)来研究不同特征对于模型预测价差的重要性. 我们将使用os数据进行测试,考虑到is和os的表现具有较高的一致性,这个选择不会造成麻烦.

# %%
# 首先计算原始模型的表现
corr = []
for i in range(len(x_test)):
    corr.append(np.corrcoef(model(x_test[i]).detach().cpu().numpy()[:,0], y_test[i].cpu().numpy()[:,0])[0,1])
print('model: {:.4f}'.format(np.mean(corr)))
nor = np.mean(corr)

# 对每个特征对换,计算表现以及下降的比例
for j in range(4):
    for i in range(len(x_test)):
        x_tmp = x_test[i]
        x_tmp[:,j] = torch.flip(x_tmp[:,j],dims=[0])
        corr.append(np.corrcoef(model(x_tmp).detach().cpu().numpy()[:,0], y_test[i].cpu().numpy()[:,0])[0,1])
        x_tmp[:,j] = torch.flip(x_tmp[:,j],dims=[0])
    print('{}: {:.4f}'.format(j, np.mean(corr)), (1-np.mean(corr)/nor)*100)
# Out:
# model: 0.9318
# 0: 0.9291 0.28758358157313646
# 1: 0.9301 0.18601228595827024
# 2: 0.9294 0.2573704977122171
# 3: 0.7273 21.951058199542484
